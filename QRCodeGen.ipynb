# %% [markdown]
# <a href="https://colab.research.google.com/github/JaspreetMaan14/QR-Code-Generator/blob/main/QRCodeGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyqrcode pypng

# %%
# Import the necessary modules
import pyqrcode
from PIL import Image
from IPython.display import display

# Define the data
data = "https://github.com/JaspreetMaan14"

# Create QR code
qr = pyqrcode.create(data)

# Save the QR code as a PNG file
qr.png("QR.png", scale=5)

# Display the QR code in the notebook
img = Image.open("QR.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=205x205>
